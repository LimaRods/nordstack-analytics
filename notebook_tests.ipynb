# %%
import pandas as pd
import os

# %%
df_clients = pd.read_csv('seed_data/raw_customers.csv')

# %%
df_clients
# Out:
#     customer_id  customer_name                        email country  \
# 0         C0001      Noah Berg       noah.berg1@example.com      FR
# 1         C0002    Lucas Rossi     lucas.rossi2@example.com      SE
# 2         C0003     Nora Costa      nora.costa3@example.com      NL
# 3         C0004  Olivia Dubois   olivia.dubois4@example.com      DE
# 4         C0005     Aiden Berg      aiden.berg5@example.com      PT
# ..          ...            ...                          ...     ...
# 116       C0117    Hugo Dubois   hugo.dubois117@example.com      IT
# 117       C0118   Lena Nilsson  lena.nilsson118@example.com      PL
# 118       C0119    Clara Weber   clara.weber119@example.com      FI
# 119       C0120    Hugo Moreau   hugo.moreau120@example.com      NO
# 120       C0023   Sofia Santos   sofia.santos23@example.com      ES
#
#      created_at
# 0    2024-09-07
# 1    2024-03-30
# 2    2024-01-31
# 3    2025-06-01
# 4    2024-07-22
# ..          ...
# 116  2024-11-25
# ...

# %%
df_inv = pd.read_csv('seed_data/raw_invoices.csv')
df_inv
# Out:
#      invoice_id subscription_id invoice_date  amount currency  status
# 0       I000001          S00001   2024-10-20    29.0      EUR  failed
# 1       I000002          S00001   2024-11-20    29.0      EUR    paid
# 2       I000003          S00001   2024-12-20    29.0      EUR    paid
# 3       I000004          S00001   2025-01-20    29.0      EUR    paid
# 4       I000005          S00001   2025-02-20    29.0      EUR    paid
# ...         ...             ...          ...     ...      ...     ...
# 2850    I002851          S00174   2026-03-11   299.0      EUR    paid
# 2851    I002852          S00174   2026-04-11   299.0      EUR    paid
# 2852    I002853          S00174   2026-05-11   299.0      EUR    paid
# 2853    I002854          S00174   2026-06-11   299.0      EUR    paid
# 2854    I002855          S00174   2026-07-11   299.0      EUR    open
#
# [2855 rows x 6 columns]

# %%
df_subs = pd.read_csv('seed_data/raw_subscriptions.csv')
df_subs
# Out:
#     subscription_id customer_id plan_name  monthly_price  start_date  \
# 0            S00001       C0001   starter           29.0  2024-10-20
# 1            S00002       C0002   starter           29.0  2024-04-01
# 2            S00003       C0003   starter           29.0  2024-02-29
# 3            S00004       C0004     scale          299.0  2025-07-15
# 4            S00005       C0005     scale          299.0  2024-09-04
# ..              ...         ...       ...            ...         ...
# 170          S00171       C0118   starter           29.0  2024-09-22
# 171          S00172       C0119    growth           99.0  2024-04-24
# 172          S00173       C0119   starter           29.0  2025-01-18
# 173          S00174       C0120     scale          299.0  2025-01-11
# 174          S00006       C0006   starter           29.0  2025-05-23
#
#        end_date     status
# 0           NaN     active
# 1           NaN     active
# 2           NaN     active
# ...
